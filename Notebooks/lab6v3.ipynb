# %% [markdown]
# ### ESMA 3016
# ### Lab6 : Calculo de Medidas estadisticas
# ### Edgar Acuna
# ####  Septiembre 2019
# #### Se usaran las librerias pandas, numpy y scipy para calcular medidas estadistica de centralidad y de dispersion

# %%
import pandas as pd
import numpy as np
from scipy import stats

# %%
#este cojunto de datos esta disponible en kaggle.com
df=pd.read_csv("http://academic.uprm.edu/eacuna/student-por.csv",sep=",")

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
# school        649 non-null object
# sex           649 non-null object
# age           649 non-null int64
# address       649 non-null object
# famsize       649 non-null object
# Pstatus       649 non-null object
# Medu          649 non-null int64
# Fedu          649 non-null int64
# Mjob          649 non-null object
# Fjob          649 non-null object
# reason        649 non-null object
# guardian      649 non-null object
# traveltime    649 non-null int64
# studytime     649 non-null int64
# failures      649 non-null int64
# schoolsup     649 non-null object
# famsup        649 non-null object
# paid          649 non-null object
# activities    649 non-null object
# nursery       649 non-null object
# higher        649 non-null object
# internet      649 non-null object
# romantic      649 non-null object
# famrel        649 non-null int64
# freetime      649 non-null int64
# goout         649 non-null int64
# Dalc          649 non-null int64
# Walc          649 non-null int64
# health        649 non-null int64
# absences      649 non-null int64
# G1            649 non-null int64
# G2            649 non-null int64
# G3            649 non-null int64
# dtypes: int64(16), object(17)
# memory usage: 167.4+ KB

# %%
#Dimension de la base de datos
print(df.shape)
# Out:
# (649, 33)

# %% [markdown]
# $$\bar {x}=\frac{\sum_i^n x_i}{n}$$

# %%
#Promedio de la variable age
np.mean(df['age'])
# Out:
# 16.7442218798151

# %%
df.age.mean()
# Out:
# 16.7442218798151

# %%
#Mediana de la variable age
np.median(df['age'])
# Out:
# 17.0

# %%
df.age.median()
# Out:
# 17.0

# %%
#Calulo de la media usando 
stats.describe(df['age'])[2]
# Out:
# 16.7442218798151

# %%
#calculando la moda de la variable ag
stats.mode(df['age'])
# Out:
# ModeResult(mode=array([17], dtype=int64), count=array([179]))

# %%
#Calculando la moda de la variable school
stats.mode(df['school'])[0]
# Out:
# array(['GP'], dtype=object)

# %%
#Calculando la moda usando pandas
df.school.mode()
# Out:
# 0    GP
# dtype: object

# %%
#Otra manera de calcular la moda
df.age.value_counts().index[0]
# Out:
# 17

# %%
x=[3,5,6,7,3,11,3,5,5]
d={'varx': x}
df1=pd.DataFrame(data=d)
df1
df1.varx.mode()
# Out:
# 0    3
# 1    5
# dtype: int64

# %%
df1.varx.value_counts().index[0]
# Out:
# 5

# %%
#calculando la media podada del 10% de la variable age
stats.trim_mean(df['age'],0.1)
# Out:
# 16.700575815738965

# %%
#Calulando la varianza de la variable age usando numpy
np.var(df['age'])
# Out:
# 1.4815729307385221

# %%
#Calculando la varianza de la variable age usando stats
varianza=stats.describe(df['age'])[3]
print( "la varianza es:", varianza)
# Out:
# la varianza es: 1.483859308718066

# %% [markdown]
# ### La diferencia de los calculos de la varianza es que en numpy por defecto en la formula de la varianza dividen entre n en cambio en stats dividen entre n-1. En la siguiente celda, hacemos que salgan iguales

# %%
#Calculando la varianza de la variable age usando numpy pero dividienedo entre n-1
np.var(df['age'],ddof=1)
# Out:
# 1.483859308718057

# %%
#Calculando la varianza usando pandas
df.age.var()
# Out:
# 1.483859308718057

# %%
#Calculando la desviacion estandar de la variable age. El modulo stats no calcula la desviaicon estandar
np.std(df['age'],ddof=1)
# Out:
# 1.2181376394800618

# %%
#Standar deviation usando pandas
df.age.std()
# Out:
# 1.2181376394800618

# %%
x1=[8,12,15,17,25,31]
np.var(x1,ddof=1)
# Out:
# 72.8

# %%
x2=[1008,1012,1015,1017,1025,1031]
np.var(x2,ddof=1)
# Out:
# 72.8

# %%
#Calculando el coeficiente de variacion
stats.variation(df['age'])*100
# Out:
# 7.269366194936092

# %%
stats.variation(x1)*100
# Out:
# 43.27156090943675

# %%
stats.variation(x2)*100
# Out:
# 0.7651160082218679

# %%
#Primer Criterio para outliers
lower=np.mean(df['age'])-3*np.std(df['age'],ddof=1)
upper=np.mean(df['age'])+3*np.std(df['age'],ddof=1) 
print("El intervalo donde caen los datos que NO son outliers es:", "\n",lower,"-",upper)
# Out:
# El intervalo donde caen los datos que NO son outliers es:
#  13.089808961374915 - 20.398634798255287

# %%
lower1=df.age.mean()-3*df.age.std()
upper1=df.age.mean()+3*df.age.std()  
print("El intervalo donde caen los datos que NO son outliers es:", "\n",lower1,"-",upper1)
# Out:
# El intervalo donde caen los datos que NO son outliers es:
#  13.089808961374915 - 20.398634798255287

# %%
#Identificando outliers
for a in df['age']:
    if (a<lower or a>upper):
        print ("outlier",a)
# Out:
# outlier 22
# outlier 21
# outlier 21
